# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/drive/MyDrive/10-04-2024/players_15.csv')
# Out:
# <ipython-input-2-11b51e20e06c>:1: DtypeWarning: Columns (104) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/drive/MyDrive/10-04-2024/players_15.csv')

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini               CF
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, LM
# 2          A. Robben                         Arjen Robben       RM, LM, RW
# 3     Z. Ibrahimović                   Zlatan Ibrahimović               ST
# 4           M. Neuer                   Manuel Peter Neuer               GK
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %% [markdown]
# 1. Youngest, Oldest Player

# %%
df[df.age==min(df.age)]['short_name']
# Out:
# 3743          J. Bakela
# 6343      B. Ould-Chikh
# 11800       David Muñoz
# 12367         R. Ledson
# 12869      H. Lorentzen
# 12999       Iván Villar
# 13550        M. Nikolic
# 13688     N. Stankevich
# 13946       S. Svendsen
# 14112          T. Moore
# 14171      D. Sommariva
# 14173       B. Saavedra
# 14371       B. Rahhaoui
# 14784         D. Alessi
# 14874          R. Henry
# 14883        C. Wighton
# 14900        J. Ortmark
# 14914            F. Bay
# 15138      D. Armstrong
# 15288    F. Sachpekidis
# 15435         S. Wright
# 15596           E. Osam
# 15717      B. Drągowski
# 15775        G. Poynton
# 15779          N. Flint
# 15836          B. Silva
# 15837        H. Kurucay
# 16021       E. Tognazzi
# 16107     C. Riley-Lowe
# 16118        J. Burgess
# 16148        L. Pilling
# Name: short_name, dtype: object

# %%
df[df.age==max(df.age)]['short_name']
# Out:
# 3403      Kim Byung Ji
# 10365      A. Pierobon
# 15839       P. Mathers
# 16143    B. Richardson
# Name: short_name, dtype: object

# %% [markdown]
# 2. Name the player having the highest wage

# %%
df[df.wage_eur==max(df.wage_eur)]['short_name']
# Out:
# 0    L. Messi
# Name: short_name, dtype: object

# %% [markdown]
# 3. Find and remove all duplicates

# %%
"""df.duplicated().sum(axix=0)
   df.drop_duplicates()
   df.duplicated.sum()"""
df.duplicated().sum(axis=0)
# Out:
# 0

# %%
df =df.drop_duplicates()

# %%
df.duplicated().sum(axis=0)
# Out:
# 0

# %% [markdown]
# 4. List out top 10 players based on POT

# %%
df.sort_values(by='potential',ascending=False).head(10)
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 31     198710  https://sofifa.com/player/198710/james-rodrigu...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 44     192318  https://sofifa.com/player/192318/mario-gotze/1...
# 16     173731  https://sofifa.com/player/173731/gareth-bale/1...
# 6      176580  https://sofifa.com/player/176580/luis-suarez/1...
# 29     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 11     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 30     192119  https://sofifa.com/player/192119/thibaut-court...
# 2        9014  https://sofifa.com/player/9014/arjen-robben/15...
#
#            short_name                            long_name player_positions  \
# 0            L. Messi       Lionel Andrés Messi Cuccittini               CF
# 31       J. Rodríguez          James David Rodríguez Rubio          CAM, RW
# ...

# %% [markdown]
# 5. Create newdf with 2 column--'Name','POT'

# %%
new_df=df[['short_name','potential']]

# %%
new_df.head(2)
# Out:
#           short_name  potential
# 0           L. Messi         95
# 1  Cristiano Ronaldo         92

# %% [markdown]
# 6. Plot x axis-> 10 player names, y axis->their potential

# %%
plt.figure(figsize=(20,20))
plt.bar(df.short_name.head(10), df.potential.head(10))
plt.grid()

# %%
#y axis-->wage
plt.figure(figsize=(15,15))
plt.bar(df.short_name.head(10), df.wage_eur.head(10))
plt.grid()

# %% [markdown]
# 7. The player who has scored the highest no of goals

# %%
# df.head(3)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age',
#        ...
#        'lcb', 'cb', 'rcb', 'rb', 'gk', 'player_face_url', 'club_logo_url',
#        'club_flag_url', 'nation_logo_url', 'nation_flag_url'],
#       dtype='object', length=110)

# %%
df[df.overall==max(df.overall)]['short_name']
# Out:
# 0    L. Messi
# Name: short_name, dtype: object

# %% [markdown]
# 8. Find all the players whose potential is more than or equal to 90

# %%
df[df.potential>=90]['short_name']
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             A. Robben
# 3        Z. Ibrahimović
# 4              M. Neuer
# 6             L. Suárez
# 11            E. Hazard
# 16              G. Bale
# 29               Neymar
# 30          T. Courtois
# 31         J. Rodríguez
# 44             M. Götze
# Name: short_name, dtype: object

# %% [markdown]
# 9. Find all the players whose potential is more than to 90 and age less than 20

# %%
df[df.potential>=50][df.age<20]
# Out:
# <ipython-input-56-94f49fb921f2>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.potential>=50][df.age<20]
#        sofifa_id                                         player_url  \
# 286       202652  https://sofifa.com/player/202652/raheem-sterli...
# 880       209329  https://sofifa.com/player/209329/matheus-doria...
# 883       210935  https://sofifa.com/player/210935/domenico-bera...
# 884       211368  https://sofifa.com/player/211368/armindo-tue-n...
# 885       212198  https://sofifa.com/player/212198/bruno-miguel-...
# ...          ...                                                ...
# 16148     220939  https://sofifa.com/player/220939/luke-pilling/...
# 16149     222997  https://sofifa.com/player/222997/marcus-maier/...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16153     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
#
# ...

# %%
df[(df.potential>=90 ) & (df.age<20)]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# 10. All the players whose value>10 but wage<52

# %%
df[(df.value_eur>=10000 ) & (df.wage_eur<20000)]
# Out:
#        sofifa_id                                         player_url  \
# 561       153934  https://sofifa.com/player/153934/francisco-med...
# 725       146458  https://sofifa.com/player/146458/roberto-fdez-...
# 1155        1099  https://sofifa.com/player/1099/marco-di-vaio/1...
# 1168       20551  https://sofifa.com/player/20551/andreas-isakss...
# 1234      146759  https://sofifa.com/player/146759/ivan-sanchez-...
# ...          ...                                                ...
# 16149     222997  https://sofifa.com/player/222997/marcus-maier/...
# 16150     220806  https://sofifa.com/player/220806/ellis-redman/...
# 16151     225509  https://sofifa.com/player/225509/aaron-collins...
# 16153     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 16154     222947  https://sofifa.com/player/222947/tom-davies/15...
#
#         short_name                     long_name player_positions  overall  \
# ...

# %% [markdown]
# 11. Heatmap

# %%
sns.heatmap(df[['overall','potential','value_eur','wage_eur','age']].corr(), annot=True, cmap="Greens")
# Out:
# <Axes: >

# %%
df[['overall','potential','value_eur','wage_eur','age']].corr()
# Out:
#             overall  potential  value_eur  wage_eur       age
# overall    1.000000   0.803952   0.575845  0.714208  0.436976
# potential  0.803952   1.000000   0.516469  0.625330 -0.072417
# value_eur  0.575845   0.516469   1.000000  0.904547  0.135278
# wage_eur   0.714208   0.625330   0.904547  1.000000  0.203047
# age        0.436976  -0.072417   0.135278  0.203047  1.000000
